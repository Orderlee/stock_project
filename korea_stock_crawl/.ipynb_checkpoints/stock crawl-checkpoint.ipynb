# %%
import pandas as pd
code_df = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13',
                       header=0)[0]
code_df.종목코드=code_df.종목코드.map('{:06d}'.format)

code_df=code_df[['회사명','종목코드']]

code_df=code_df.rename(columns={'회사명':'name','종목코드':'code'})
code_df.to_csv('D:/python/stock/stock.csv', index=False, encoding='ms949')
code_df.head()

# %%
import cx_Oracle #오라클 접속 모듈 로딩
#오라클 서버에 접속 '아이디/비번@호스트:포트번호/sid'
conn=cx_Oracle.connect('hr/hr@localhost:1521/xe')
cursor=conn.cursor() #커서생성
sql='''
select * from stock
'''
cursor.execute(sql) #sql 명령어 실행
rows=cursor.fetchall() #결과셋을 리스트로 저장
print('회사\t코드')
for row in rows:
    print('{}\t{}'.format(row[0],row[1]))
#데이터베이스 관련 리소스 정리
cursor.close()
conn.close()

# %%
import requests
from bs4 import BeautifulSoup

plusUrl = input('종목코드:')

def refine_price(text):
    price=int(text.replace(",",""))
    return price

result=[]
for i in range(10):
    url='https://finance.naver.com/item/sise_day.nhn?code='+str(plusUrl)+'&page={}'.format(i)
    response=requests.get(url)
    text=response.text
    html=BeautifulSoup(text,'html.parser')
    table0=html.find_all("tr",{"onmouseover":"mouseOver(this)"})
    print(url)
    
    for tr in table0:
        date= tr.find_all('td')[0].text
        temp=[]  
        
        for idx,td in enumerate(tr.find_all('td')[1:]):
            if idx==1:
                try:
                    #print(td.find()['alt'])
                    temp.append(td.find()['alt'])
                except: 
                    temp.append('')
                
            price=refine_price(td.text)
            #print(price)
            temp.append(price)
        
        #print([date]+temp)
        result.append([date]+temp)
        
print(result)

# %%
df_temp=pd.DataFrame(result,columns=['날짜','종가','상승/하락','전일비','시가','고가','저가','거래량'])
df_temp

# %%
#https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100

# %%
from korea_news_crawler.articlecrawler import ArticleCrawler

Crawler = ArticleCrawler()  
Crawler.set_category("정치", "IT과학", "economy","IT과학","사회","세계")  
Crawler.set_date_range(2019, 1, 2020, 3)  
Crawler.start()
# Out:
# {'start_year': 2019, 'start_month': 1, 'end_year': 2020, 'end_month': 3}

# %%
from time import sleep
from bs4 import BeautifulSoup
from multiprocessing import Process
from korea_news_crawler.exceptions import *
from korea_news_crawler.articleparser import ArticleParser
from korea_news_crawler.writer import Writer
import os
import platform
import calendar
import requests
import re


class ArticleCrawler(object):
    def __init__(self):
        self.categories = {'정치': 100, '경제': 101, '사회': 102, '생활문화': 103, '세계': 104, 'IT과학': 105, '오피니언': 110,
                           'politics': 100, 'economy': 101, 'society': 102, 'living_culture': 103, 'world': 104, 'IT_science': 105, 'opinion': 110}
        self.selected_categories = []
        self.date = {'start_year': 0, 'start_month': 0, 'end_year': 0, 'end_month': 0}
        self.user_operating_system = str(platform.system())

    def set_category(self, *args):
        for key in args:
            if self.categories.get(key) is None:
                raise InvalidCategory(key)
        self.selected_categories = args

    def set_date_range(self, start_year, start_month, end_year, end_month):
        args = [start_year, start_month, end_year, end_month]
        if start_year > end_year:
            raise InvalidYear(start_year, end_year)
        if start_month < 1 or start_month > 12:
            raise InvalidMonth(start_month)
        if end_month < 1 or end_month > 12:
            raise InvalidMonth(end_month)
        if start_year == end_year and start_month > end_month:
            raise OverbalanceMonth(start_month, end_month)
        for key, date in zip(self.date, args):
            self.date[key] = date
        print(self.date)

    @staticmethod
    def make_news_page_url(category_url, start_year, end_year, start_month, end_month):
        made_urls = []
        for year in range(start_year, end_year + 1):
            if start_year == end_year:
                year_startmonth = start_month
                year_endmonth = end_month
            else:
                if year == start_year:
                    year_startmonth = start_month
                    year_endmonth = 12
                elif year == end_year:
                    year_startmonth = 1
                    year_endmonth = end_month
                else:
                    year_startmonth = 1
                    year_endmonth = 12
            
            for month in range(year_startmonth, year_endmonth + 1):
                for month_day in range(1, calendar.monthrange(year, month)[1] + 1):
                    if len(str(month)) == 1:
                        month = "0" + str(month)
                    if len(str(month_day)) == 1:
                        month_day = "0" + str(month_day)
                        
                    # 날짜별로 Page Url 생성
                    url = category_url + str(year) + str(month) + str(month_day)

                    # totalpage는 네이버 페이지 구조를 이용해서 page=10000으로 지정해 totalpage를 알아냄
                    # page=10000을 입력할 경우 페이지가 존재하지 않기 때문에 page=totalpage로 이동 됨 (Redirect)
                    totalpage = ArticleParser.find_news_totalpage(url + "&page=10000")
                    for page in range(1, totalpage + 1):
                        made_urls.append(url + "&page=" + str(page))
        return made_urls

    @staticmethod
    def get_url_data(url, max_tries=10):
        remaining_tries = int(max_tries)
        while remaining_tries > 0:
            try:
                return requests.get(url)
            except requests.exceptions:
                sleep(60)
            remaining_tries = remaining_tries - 1
        raise ResponseTimeout()

    def crawling(self, category_name):
        # Multi Process PID
        print(category_name + " PID: " + str(os.getpid()))    

        writer = Writer(category_name=category_name, date=self.date)

        # 기사 URL 형식
        url = "http://news.naver.com/main/list.nhn?mode=LSD&mid=sec&sid1=" + str(self.categories.get(category_name)) + "&date="

        # start_year년 start_month월 ~ end_year의 end_month 날짜까지 기사를 수집합니다.
        day_urls = self.make_news_page_url(url, self.date['start_year'], self.date['end_year'], self.date['start_month'], self.date['end_month'])
        print(category_name + " Urls are generated")
        print("The crawler starts")

        for URL in day_urls:

            regex = re.compile("date=(\d+)")
            news_date = regex.findall(URL)[0]

            request = self.get_url_data(URL)

            document = BeautifulSoup(request.content, 'html.parser')

            # html - newsflash_body - type06_headline, type06
            # 각 페이지에 있는 기사들 가져오기
            post_temp = document.select('.newsflash_body .type06_headline li dl')
            post_temp.extend(document.select('.newsflash_body .type06 li dl'))
            
            # 각 페이지에 있는 기사들의 url 저장
            post = []
            for line in post_temp:
                post.append(line.a.get('href')) # 해당되는 page에서 모든 기사들의 URL을 post 리스트에 넣음
            del post_temp

            for content_url in post:  # 기사 URL
                # 크롤링 대기 시간
                sleep(0.01)
                
                # 기사 HTML 가져옴
                request_content = self.get_url_data(content_url)
                try:
                    document_content = BeautifulSoup(request_content.content, 'html.parser')
                except:
                    continue

                try:
                    # 기사 제목 가져옴
                    tag_headline = document_content.find_all('h3', {'id': 'articleTitle'}, {'class': 'tts_head'})
                    text_headline = ''  # 뉴스 기사 제목 초기화
                    text_headline = text_headline + ArticleParser.clear_headline(str(tag_headline[0].find_all(text=True)))
                    if not text_headline:  # 공백일 경우 기사 제외 처리
                        continue

                    # 기사 본문 가져옴
                    tag_content = document_content.find_all('div', {'id': 'articleBodyContents'})
                    text_sentence = ''  # 뉴스 기사 본문 초기화
                    text_sentence = text_sentence + ArticleParser.clear_content(str(tag_content[0].find_all(text=True)))
                    if not text_sentence:  # 공백일 경우 기사 제외 처리
                        continue

                    # 기사 언론사 가져옴
                    tag_company = document_content.find_all('meta', {'property': 'me2:category1'})
                    text_company = ''  # 언론사 초기화
                    text_company = text_company + str(tag_company[0].get('content'))
                    if not text_company:  # 공백일 경우 기사 제외 처리
                        continue
                        
                    # CSV 작성
                    wcsv = writer.get_writer_csv()
                    wcsv.writerow([news_date, category_name, text_company, text_headline, text_sentence, content_url])
                    
                    del text_company, text_sentence, text_headline
                    del tag_company 
                    del tag_content, tag_headline
                    del request_content, document_content

                except Exception as ex:  # UnicodeEncodeError ..
                    # wcsv.writerow([ex, content_url])
                    del request_content, document_content
                    pass
        writer.close()

    def start(self):
        # MultiProcess 크롤링 시작
        for category_name in self.selected_categories:
            proc = Process(target=self.crawling, args=(category_name,))
            proc.start()


if __name__ == "__main__":
    Crawler = ArticleCrawler()
    Crawler.set_category("생활문화", "IT과학")
    Crawler.set_date_range(2017, 1, 2018, 4)
    Crawler.start()
# Out:
# {'start_year': 2017, 'start_month': 1, 'end_year': 2018, 'end_month': 4}

# %%
import csv
import platform


class Writer(object):
    def __init__(self, category_name, date):
        self.user_operating_system = str(platform.system())

        self.category_name = category_name

        self.date = date
        self.save_start_year = self.date['start_year']
        self.save_end_year = self.date['end_year']
        self.save_start_month = None
        self.save_end_month = None
        self.initialize_month()

        self.file = None
        self.initialize_file()

        self.wcsv = csv.writer(self.file)

    def initialize_month(self):
        if len(str(self.date['start_month'])) == 1:
            self.save_start_month = "0" + str(self.date['start_month'])
        else:
            self.save_start_month = str(self.date['start_month'])
        if len(str(self.date['end_month'])) == 1:
            self.save_end_month = "0" + str(self.date['end_month'])
        else:
            self.save_end_month = str(self.date['end_month'])

    def initialize_file(self):
        if self.user_operating_system == "Windows":
            self.file = open('Article_' + self.category_name + '_' + str(self.save_start_year) + self.save_start_month
                             + '_' + str(self.save_end_year) + self.save_end_month + '.csv', 'w', encoding='euc-kr',
                             newline='')
        # Other OS uses utf-8
        else:
            self.file = open('Article_' + self.category_name + '_' + str(self.save_start_year) + self.save_start_month
                             + '_' + str(self.save_end_year) + self.save_end_month + '.csv', 'w', encoding='utf-8',
                             newline='')

    def get_writer_csv(self):
        return self.wcsv

    def close(self):
        self.file.close()

# %%
from bs4 import BeautifulSoup
import requests
import re


class ArticleParser(object):
    special_symbol = re.compile('[\{\}\[\]\/?,;:|\)*~`!^\-_+<>@\#$&▲▶◆◀■【】\\\=\(\'\"]')
    content_pattern = re.compile('본문 내용|TV플레이어| 동영상 뉴스|flash 오류를 우회하기 위한 함수 추가function  flash removeCallback|tt|앵커 멘트|xa0')

    @classmethod
    def clear_content(cls, text):
        # 기사 본문에서 필요없는 특수문자 및 본문 양식 등을 다 지움
        newline_symbol_removed_text = text.replace('\\n', '').replace('\\t', '').replace('\\r', '')
        special_symbol_removed_content = re.sub(cls.special_symbol, ' ', newline_symbol_removed_text)
        end_phrase_removed_content = re.sub(cls.content_pattern, '', special_symbol_removed_content)
        blank_removed_content = re.sub(' +', ' ', end_phrase_removed_content).lstrip()  # 공백 에러 삭제
        reversed_content = ''.join(reversed(blank_removed_content))  # 기사 내용을 reverse 한다.
        content = ''
        for i in range(0, len(blank_removed_content)):
            # reverse 된 기사 내용중, ".다"로 끝나는 경우 기사 내용이 끝난 것이기 때문에 기사 내용이 끝난 후의 광고, 기자 등의 정보는 다 지움
            if reversed_content[i:i + 2] == '.다':
                content = ''.join(reversed(reversed_content[i:]))
                break
        return content

    @classmethod
    def clear_headline(cls, text):
        # 기사 제목에서 필요없는 특수문자들을 지움
        newline_symbol_removed_text = text.replace('\\n', '').replace('\\t', '').replace('\\r', '')
        special_symbol_removed_headline = re.sub(cls.special_symbol, '', newline_symbol_removed_text)
        return special_symbol_removed_headline

    @classmethod
    def find_news_totalpage(cls, url):
        # 당일 기사 목록 전체를 알아냄
        try:
            totlapage_url = url
            request_content = requests.get(totlapage_url)
            document_content = BeautifulSoup(request_content.content, 'html.parser')
            headline_tag = document_content.find('div', {'class': 'paging'}).find('strong')
            regex = re.compile(r'<strong>(?P<num>\d+)')
            match = regex.findall(str(headline_tag))
            return int(match[0])
        except Exception:
            return 0

# %%
import requests
from bs4 import BeautifulSoup


for i in range(100,105,1):
    url='https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1={}'.format(i)
    
    for j in range(1,5):
        link=url+'#&date=%2000:00:00&page={}'.format(j)
        result = requests.get(link)
        article1 = BeautifulSoup(result.content, "html.parser")
        lis=article1.select('a')
        
        for item in lis:
            try:
                a=item['href']
                if 'read.nhn' in a:
                    print(a)
            except:
                pass
        break
        
#         links="https://news.naver.com/"+a
#         result2=request.get(links)
#         bs_doc=BeautifulSoup(result2.content,"html.parser")
#         times=bs_doc.find("span",{"class":"t11"})
#         b=times.text.replace('\n''')
#         c=[int(s) for s in a.split() if s.isdigit() and len(s) ==4]
#         b=c[0]
#         titles=bs_doc.find("h3",{"class":"tt_head"})
#         c=titles.text.replace('\n','').replace('?','').replace('*','').replace('/','').replace("\\",'').replace('<','').replace('>','').split('-')[0]
#         c=c.lstrip().rstrip()
#         docs=bs_doc.find("div",{"class":"_article_body_contents"})
        
#         f = open('D:/python/stock/'+str(a)+'-'+str(b)+'.txt', 'w',encoding='utf-8')
        
#         fname = f
#         f.write(txt)
#         f.close()
# Out:
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=052&aid=0001422069
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=056&aid=0010812087
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=008&aid=0004386826
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=031&aid=0000532261
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512435
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=421&aid=0004554943
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078614
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078614
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=018&aid=0004609799
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=011&aid=0003717589
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=025&aid=0002989066
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512662
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512662
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=016&aid=0001656195
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=014&aid=0004399922
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=421&aid=0004555346
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078569
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078569
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=047&aid=0002263946
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512189
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=025&aid=0002989088
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512435
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512435
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=018&aid=0004609860
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=005&aid=0001306299
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=021&aid=0002422879
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=022&aid=0003452173
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=022&aid=0003452173
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=005&aid=0001306234
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=020&aid=0003278388
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=366&aid=0000500742
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=469&aid=0000482890
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=469&aid=0000482890
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=015&aid=0004316328
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=422&aid=0000421862
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=029&aid=0002591444
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=421&aid=0004555291
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=421&aid=0004555291
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=214&aid=0001027244
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=011&aid=0003717684
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512359
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=023&aid=0003519626
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=023&aid=0003519626
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=421&aid=0004555185
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=421&aid=0004555185
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=422&aid=0000421993
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=422&aid=0000421819
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=422&aid=0000421448
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=422&aid=0000421272
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011510365&date=20200331&type=1&rankingSeq=1&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989076&date=20200331&type=1&rankingSeq=2&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519530&date=20200331&type=0&rankingSeq=3&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078569&date=20200331&type=1&rankingSeq=4&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422069&date=20200331&type=2&rankingSeq=5&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=011&aid=0003717589&date=20200331&type=1&rankingSeq=6&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519620&date=20200331&type=1&rankingSeq=7&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422058&date=20200331&type=1&rankingSeq=8&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=417&aid=0000524957&date=20200331&type=1&rankingSeq=9&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=056&aid=0010812075&date=20200331&type=1&rankingSeq=10&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989081&date=20200331&type=1&rankingSeq=1&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004316266&date=20200331&type=1&rankingSeq=2&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519591&date=20200331&type=1&rankingSeq=3&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=057&aid=0001438550&date=20200331&type=0&rankingSeq=4&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004316243&date=20200331&type=0&rankingSeq=5&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519566&date=20200331&type=1&rankingSeq=6&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422045&date=20200331&type=1&rankingSeq=7&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004653155&date=20200331&type=1&rankingSeq=8&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=215&aid=0000860496&date=20200331&type=1&rankingSeq=9&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=055&aid=0000804591&date=20200331&type=1&rankingSeq=10&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078580&date=20200331&type=1&rankingSeq=1&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512089&date=20200331&type=1&rankingSeq=2&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009788105&date=20200331&type=0&rankingSeq=3&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512409&date=20200331&type=1&rankingSeq=4&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004653105&date=20200331&type=1&rankingSeq=5&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078521&date=20200331&type=1&rankingSeq=6&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343129&date=20200331&type=1&rankingSeq=7&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512446&date=20200331&type=1&rankingSeq=8&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512185&date=20200331&type=1&rankingSeq=9&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=031&aid=0000532237&date=20200331&type=1&rankingSeq=10&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343140&date=20200331&type=1&rankingSeq=1&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0004609132&date=20200331&type=1&rankingSeq=2&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=009&aid=0004547128&date=20200330&type=1&rankingSeq=3&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002988743&date=20200330&type=1&rankingSeq=4&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009787940&date=20200331&type=1&rankingSeq=5&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=296&aid=0000044661&date=20200331&type=1&rankingSeq=6&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009787980&date=20200331&type=1&rankingSeq=7&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=022&aid=0003452029&date=20200331&type=1&rankingSeq=8&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343161&date=20200331&type=1&rankingSeq=9&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=215&aid=0000860620&date=20200331&type=1&rankingSeq=10&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=437&aid=0000234877&date=20200331&type=2&rankingSeq=1&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512525&date=20200331&type=1&rankingSeq=2&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078551&date=20200331&type=1&rankingSeq=3&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989010&date=20200331&type=1&rankingSeq=4&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002988975&date=20200331&type=1&rankingSeq=5&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=032&aid=0003001032&date=20200331&type=1&rankingSeq=6&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=449&aid=0000189238&date=20200331&type=1&rankingSeq=7&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=056&aid=0010812034&date=20200331&type=1&rankingSeq=8&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343235&date=20200331&type=1&rankingSeq=9&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=422&aid=0000421982&date=20200331&type=2&rankingSeq=10&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989078&date=20200331&type=1&rankingSeq=1&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000500358&date=20200331&type=1&rankingSeq=2&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000500688&date=20200331&type=1&rankingSeq=3&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0004386672&date=20200331&type=1&rankingSeq=4&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=138&aid=0002084396&date=20200331&type=1&rankingSeq=5&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519618&date=20200331&type=1&rankingSeq=6&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=005&aid=0001306221&date=20200331&type=1&rankingSeq=7&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0004609744&date=20200331&type=1&rankingSeq=8&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=029&aid=0002591244&date=20200330&type=1&rankingSeq=9&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=092&aid=0002184864&date=20200331&type=1&rankingSeq=10&rankingSectionId=105
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078614
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512662
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078569
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=055&aid=0000804620
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=081&aid=0003078564
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=002&aid=0002128571
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=277&aid=0004653155
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=629&aid=0000020846
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=025&aid=0002989080
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=003&aid=0009787940
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=006&aid=0000101904
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512849
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=028&aid=0002491652
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=031&aid=0000532250
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=052&aid=0001422069
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=056&aid=0010812087
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=008&aid=0004386826
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=031&aid=0000532261
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512435
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=421&aid=0004554943
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=002&aid=0002128571
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=002&aid=0002128571
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=008&aid=0004386750
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=011&aid=0003717667
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=119&aid=0002392631
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=277&aid=0004653155
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=277&aid=0004653155
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=031&aid=0000532269
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=031&aid=0000532261
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=008&aid=0004386755
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=629&aid=0000020846
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=629&aid=0000020846
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=011&aid=0003717706
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=028&aid=0002491643
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=021&aid=0002422881
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=015&aid=0004316295
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=015&aid=0004316295
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=023&aid=0003519618
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=023&aid=0003519618
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=011&aid=0003717645
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=119&aid=0002392625
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=119&aid=0002392625
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=011&aid=0003717585
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=011&aid=0003717585
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=417&aid=0000525012
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=417&aid=0000525012
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=243&aid=0000009794
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=243&aid=0000009767
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=243&aid=0000009739
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=243&aid=0000009711
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011510365&date=20200331&type=1&rankingSeq=1&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989076&date=20200331&type=1&rankingSeq=2&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519530&date=20200331&type=0&rankingSeq=3&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078569&date=20200331&type=1&rankingSeq=4&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422069&date=20200331&type=2&rankingSeq=5&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=011&aid=0003717589&date=20200331&type=1&rankingSeq=6&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519620&date=20200331&type=1&rankingSeq=7&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422058&date=20200331&type=1&rankingSeq=8&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=417&aid=0000524957&date=20200331&type=1&rankingSeq=9&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=056&aid=0010812075&date=20200331&type=1&rankingSeq=10&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989081&date=20200331&type=1&rankingSeq=1&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004316266&date=20200331&type=1&rankingSeq=2&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519591&date=20200331&type=1&rankingSeq=3&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=057&aid=0001438550&date=20200331&type=0&rankingSeq=4&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004316243&date=20200331&type=0&rankingSeq=5&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519566&date=20200331&type=1&rankingSeq=6&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422045&date=20200331&type=1&rankingSeq=7&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004653155&date=20200331&type=1&rankingSeq=8&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=215&aid=0000860496&date=20200331&type=1&rankingSeq=9&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=055&aid=0000804591&date=20200331&type=1&rankingSeq=10&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078580&date=20200331&type=1&rankingSeq=1&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512089&date=20200331&type=1&rankingSeq=2&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009788105&date=20200331&type=0&rankingSeq=3&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512409&date=20200331&type=1&rankingSeq=4&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004653105&date=20200331&type=1&rankingSeq=5&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078521&date=20200331&type=1&rankingSeq=6&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343129&date=20200331&type=1&rankingSeq=7&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512446&date=20200331&type=1&rankingSeq=8&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512185&date=20200331&type=1&rankingSeq=9&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=031&aid=0000532237&date=20200331&type=1&rankingSeq=10&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343140&date=20200331&type=1&rankingSeq=1&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0004609132&date=20200331&type=1&rankingSeq=2&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=009&aid=0004547128&date=20200330&type=1&rankingSeq=3&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002988743&date=20200330&type=1&rankingSeq=4&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009787940&date=20200331&type=1&rankingSeq=5&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=296&aid=0000044661&date=20200331&type=1&rankingSeq=6&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009787980&date=20200331&type=1&rankingSeq=7&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=022&aid=0003452029&date=20200331&type=1&rankingSeq=8&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343161&date=20200331&type=1&rankingSeq=9&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=215&aid=0000860620&date=20200331&type=1&rankingSeq=10&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=437&aid=0000234877&date=20200331&type=2&rankingSeq=1&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512525&date=20200331&type=1&rankingSeq=2&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078551&date=20200331&type=1&rankingSeq=3&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989010&date=20200331&type=1&rankingSeq=4&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002988975&date=20200331&type=1&rankingSeq=5&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=032&aid=0003001032&date=20200331&type=1&rankingSeq=6&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=449&aid=0000189238&date=20200331&type=1&rankingSeq=7&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=056&aid=0010812034&date=20200331&type=1&rankingSeq=8&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343235&date=20200331&type=1&rankingSeq=9&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=422&aid=0000421982&date=20200331&type=2&rankingSeq=10&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989078&date=20200331&type=1&rankingSeq=1&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000500358&date=20200331&type=1&rankingSeq=2&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000500688&date=20200331&type=1&rankingSeq=3&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0004386672&date=20200331&type=1&rankingSeq=4&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=138&aid=0002084396&date=20200331&type=1&rankingSeq=5&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519618&date=20200331&type=1&rankingSeq=6&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=005&aid=0001306221&date=20200331&type=1&rankingSeq=7&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0004609744&date=20200331&type=1&rankingSeq=8&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=029&aid=0002591244&date=20200330&type=1&rankingSeq=9&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=092&aid=0002184864&date=20200331&type=1&rankingSeq=10&rankingSectionId=105
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078614
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512662
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078569
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=055&aid=0000804620
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=081&aid=0003078564
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=002&aid=0002128571
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=277&aid=0004653155
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=629&aid=0000020846
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=025&aid=0002989080
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=003&aid=0009787940
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=006&aid=0000101904
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512849
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=028&aid=0002491652
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=031&aid=0000532250
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=052&aid=0001422069
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=056&aid=0010812087
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=008&aid=0004386826
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=031&aid=0000532261
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512435
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=421&aid=0004554943
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=006&aid=0000101904
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=006&aid=0000101904
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=469&aid=0000482973
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512635
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512089
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512826
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512896
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=015&aid=0004316264
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512849
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512849
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=469&aid=0000482967
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512786
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=003&aid=0009788105
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=020&aid=0003278408
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=020&aid=0003278408
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=003&aid=0009787934
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=015&aid=0004316235
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512390
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=081&aid=0003078521
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=081&aid=0003078521
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=079&aid=0003343129
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=421&aid=0004555251
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=015&aid=0004316289
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=008&aid=0004386860
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=008&aid=0004386860
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=422&aid=0000421991
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=422&aid=0000421991
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=022&aid=0003452140
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=022&aid=0003452140
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512409
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512409
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=422&aid=0000421929
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=422&aid=0000421767
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=422&aid=0000421380
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=422&aid=0000421217
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011510365&date=20200331&type=1&rankingSeq=1&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989076&date=20200331&type=1&rankingSeq=2&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519530&date=20200331&type=0&rankingSeq=3&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078569&date=20200331&type=1&rankingSeq=4&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422069&date=20200331&type=2&rankingSeq=5&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=011&aid=0003717589&date=20200331&type=1&rankingSeq=6&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519620&date=20200331&type=1&rankingSeq=7&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422058&date=20200331&type=1&rankingSeq=8&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=417&aid=0000524957&date=20200331&type=1&rankingSeq=9&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=056&aid=0010812075&date=20200331&type=1&rankingSeq=10&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989081&date=20200331&type=1&rankingSeq=1&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004316266&date=20200331&type=1&rankingSeq=2&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519591&date=20200331&type=1&rankingSeq=3&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=057&aid=0001438550&date=20200331&type=0&rankingSeq=4&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004316243&date=20200331&type=0&rankingSeq=5&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519566&date=20200331&type=1&rankingSeq=6&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422045&date=20200331&type=1&rankingSeq=7&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004653155&date=20200331&type=1&rankingSeq=8&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=215&aid=0000860496&date=20200331&type=1&rankingSeq=9&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=055&aid=0000804591&date=20200331&type=1&rankingSeq=10&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078580&date=20200331&type=1&rankingSeq=1&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512089&date=20200331&type=1&rankingSeq=2&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009788105&date=20200331&type=0&rankingSeq=3&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512409&date=20200331&type=1&rankingSeq=4&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004653105&date=20200331&type=1&rankingSeq=5&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078521&date=20200331&type=1&rankingSeq=6&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343129&date=20200331&type=1&rankingSeq=7&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512446&date=20200331&type=1&rankingSeq=8&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512185&date=20200331&type=1&rankingSeq=9&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=031&aid=0000532237&date=20200331&type=1&rankingSeq=10&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343140&date=20200331&type=1&rankingSeq=1&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0004609132&date=20200331&type=1&rankingSeq=2&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=009&aid=0004547128&date=20200330&type=1&rankingSeq=3&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002988743&date=20200330&type=1&rankingSeq=4&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009787940&date=20200331&type=1&rankingSeq=5&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=296&aid=0000044661&date=20200331&type=1&rankingSeq=6&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009787980&date=20200331&type=1&rankingSeq=7&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=022&aid=0003452029&date=20200331&type=1&rankingSeq=8&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343161&date=20200331&type=1&rankingSeq=9&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=215&aid=0000860620&date=20200331&type=1&rankingSeq=10&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=437&aid=0000234877&date=20200331&type=2&rankingSeq=1&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512525&date=20200331&type=1&rankingSeq=2&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078551&date=20200331&type=1&rankingSeq=3&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989010&date=20200331&type=1&rankingSeq=4&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002988975&date=20200331&type=1&rankingSeq=5&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=032&aid=0003001032&date=20200331&type=1&rankingSeq=6&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=449&aid=0000189238&date=20200331&type=1&rankingSeq=7&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=056&aid=0010812034&date=20200331&type=1&rankingSeq=8&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343235&date=20200331&type=1&rankingSeq=9&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=422&aid=0000421982&date=20200331&type=2&rankingSeq=10&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989078&date=20200331&type=1&rankingSeq=1&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000500358&date=20200331&type=1&rankingSeq=2&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000500688&date=20200331&type=1&rankingSeq=3&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0004386672&date=20200331&type=1&rankingSeq=4&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=138&aid=0002084396&date=20200331&type=1&rankingSeq=5&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519618&date=20200331&type=1&rankingSeq=6&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=005&aid=0001306221&date=20200331&type=1&rankingSeq=7&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0004609744&date=20200331&type=1&rankingSeq=8&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=029&aid=0002591244&date=20200330&type=1&rankingSeq=9&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=092&aid=0002184864&date=20200331&type=1&rankingSeq=10&rankingSectionId=105
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078614
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512662
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078569
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=055&aid=0000804620
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=081&aid=0003078564
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=002&aid=0002128571
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=277&aid=0004653155
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=629&aid=0000020846
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=025&aid=0002989080
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=003&aid=0009787940
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=006&aid=0000101904
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512849
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=028&aid=0002491652
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=031&aid=0000532250
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=052&aid=0001422069
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=056&aid=0010812087
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=008&aid=0004386826
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=031&aid=0000532261
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512435
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=421&aid=0004554943
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=028&aid=0002491652
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=028&aid=0002491652
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=009&aid=0004548012
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=030&aid=0002875663
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=022&aid=0003452186
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=031&aid=0000532250
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=031&aid=0000532250
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=016&aid=0001656164
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=016&aid=0001656164
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=009&aid=0004547998
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=009&aid=0004547998
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=020&aid=0003278404
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=020&aid=0003278404
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=003&aid=0009787583
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=003&aid=0009787583
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=018&aid=0004609859
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=018&aid=0004609859
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=021&aid=0002422871
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=031&aid=0000532245
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=031&aid=0000532245
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=032&aid=0003000918
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=032&aid=0003000676
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=032&aid=0003000269
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=032&aid=0002999994
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=015&aid=0004315036
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=015&aid=0004311292
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=015&aid=0004303144
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=015&aid=0004299122
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011510365&date=20200331&type=1&rankingSeq=1&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989076&date=20200331&type=1&rankingSeq=2&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519530&date=20200331&type=0&rankingSeq=3&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078569&date=20200331&type=1&rankingSeq=4&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422069&date=20200331&type=2&rankingSeq=5&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=011&aid=0003717589&date=20200331&type=1&rankingSeq=6&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519620&date=20200331&type=1&rankingSeq=7&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422058&date=20200331&type=1&rankingSeq=8&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=417&aid=0000524957&date=20200331&type=1&rankingSeq=9&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=056&aid=0010812075&date=20200331&type=1&rankingSeq=10&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989081&date=20200331&type=1&rankingSeq=1&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004316266&date=20200331&type=1&rankingSeq=2&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519591&date=20200331&type=1&rankingSeq=3&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=057&aid=0001438550&date=20200331&type=0&rankingSeq=4&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004316243&date=20200331&type=0&rankingSeq=5&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519566&date=20200331&type=1&rankingSeq=6&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422045&date=20200331&type=1&rankingSeq=7&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004653155&date=20200331&type=1&rankingSeq=8&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=215&aid=0000860496&date=20200331&type=1&rankingSeq=9&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=055&aid=0000804591&date=20200331&type=1&rankingSeq=10&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078580&date=20200331&type=1&rankingSeq=1&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512089&date=20200331&type=1&rankingSeq=2&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009788105&date=20200331&type=0&rankingSeq=3&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512409&date=20200331&type=1&rankingSeq=4&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004653105&date=20200331&type=1&rankingSeq=5&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078521&date=20200331&type=1&rankingSeq=6&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343129&date=20200331&type=1&rankingSeq=7&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512446&date=20200331&type=1&rankingSeq=8&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512185&date=20200331&type=1&rankingSeq=9&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=031&aid=0000532237&date=20200331&type=1&rankingSeq=10&rankingSectionId=102
# ...
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000500358&date=20200331&type=1&rankingSeq=2&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000500688&date=20200331&type=1&rankingSeq=3&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0004386672&date=20200331&type=1&rankingSeq=4&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=138&aid=0002084396&date=20200331&type=1&rankingSeq=5&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519618&date=20200331&type=1&rankingSeq=6&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=005&aid=0001306221&date=20200331&type=1&rankingSeq=7&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0004609744&date=20200331&type=1&rankingSeq=8&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=029&aid=0002591244&date=20200330&type=1&rankingSeq=9&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=092&aid=0002184864&date=20200331&type=1&rankingSeq=10&rankingSectionId=105
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078614
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512662
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078569
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=055&aid=0000804620
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=081&aid=0003078564
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=002&aid=0002128571
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=277&aid=0004653155
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=629&aid=0000020846
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=025&aid=0002989080
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=003&aid=0009787940
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=006&aid=0000101904
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512849
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=028&aid=0002491652
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=031&aid=0000532250
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=052&aid=0001422069
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=056&aid=0010812087
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=008&aid=0004386826
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=031&aid=0000532261
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512435
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=421&aid=0004554943
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=055&aid=0000804620
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=055&aid=0000804620
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=008&aid=0004386878
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=005&aid=0001306255
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=028&aid=0002491636
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=081&aid=0003078564
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=081&aid=0003078564
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=056&aid=0010812088
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=015&aid=0004316287
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011511797
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011511926
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011511926
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=025&aid=0002989073
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=003&aid=0009788010
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=366&aid=0000500874
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=003&aid=0009787923
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=003&aid=0009787923
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=056&aid=0010812071
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=056&aid=0010812071
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=448&aid=0000294829
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=079&aid=0003343189
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=079&aid=0003343189
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011511993
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011511993
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=032&aid=0003001044
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=032&aid=0003001044
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=081&aid=0003078554
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=081&aid=0003078554
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=005&aid=0001306197
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=005&aid=0001306197
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=015&aid=0004315429
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=015&aid=0004314733
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=015&aid=0004298229
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=015&aid=0004295737
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011510365&date=20200331&type=1&rankingSeq=1&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989076&date=20200331&type=1&rankingSeq=2&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519530&date=20200331&type=0&rankingSeq=3&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078569&date=20200331&type=1&rankingSeq=4&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422069&date=20200331&type=2&rankingSeq=5&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=011&aid=0003717589&date=20200331&type=1&rankingSeq=6&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519620&date=20200331&type=1&rankingSeq=7&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422058&date=20200331&type=1&rankingSeq=8&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=417&aid=0000524957&date=20200331&type=1&rankingSeq=9&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=056&aid=0010812075&date=20200331&type=1&rankingSeq=10&rankingSectionId=100
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989081&date=20200331&type=1&rankingSeq=1&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004316266&date=20200331&type=1&rankingSeq=2&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519591&date=20200331&type=1&rankingSeq=3&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=057&aid=0001438550&date=20200331&type=0&rankingSeq=4&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004316243&date=20200331&type=0&rankingSeq=5&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519566&date=20200331&type=1&rankingSeq=6&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001422045&date=20200331&type=1&rankingSeq=7&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004653155&date=20200331&type=1&rankingSeq=8&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=215&aid=0000860496&date=20200331&type=1&rankingSeq=9&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=055&aid=0000804591&date=20200331&type=1&rankingSeq=10&rankingSectionId=101
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078580&date=20200331&type=1&rankingSeq=1&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512089&date=20200331&type=1&rankingSeq=2&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009788105&date=20200331&type=0&rankingSeq=3&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512409&date=20200331&type=1&rankingSeq=4&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004653105&date=20200331&type=1&rankingSeq=5&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078521&date=20200331&type=1&rankingSeq=6&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343129&date=20200331&type=1&rankingSeq=7&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512446&date=20200331&type=1&rankingSeq=8&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512185&date=20200331&type=1&rankingSeq=9&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=031&aid=0000532237&date=20200331&type=1&rankingSeq=10&rankingSectionId=102
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343140&date=20200331&type=1&rankingSeq=1&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0004609132&date=20200331&type=1&rankingSeq=2&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=009&aid=0004547128&date=20200330&type=1&rankingSeq=3&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002988743&date=20200330&type=1&rankingSeq=4&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009787940&date=20200331&type=1&rankingSeq=5&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=296&aid=0000044661&date=20200331&type=1&rankingSeq=6&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0009787980&date=20200331&type=1&rankingSeq=7&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=022&aid=0003452029&date=20200331&type=1&rankingSeq=8&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343161&date=20200331&type=1&rankingSeq=9&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=215&aid=0000860620&date=20200331&type=1&rankingSeq=10&rankingSectionId=103
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=437&aid=0000234877&date=20200331&type=2&rankingSeq=1&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011512525&date=20200331&type=1&rankingSeq=2&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0003078551&date=20200331&type=1&rankingSeq=3&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989010&date=20200331&type=1&rankingSeq=4&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002988975&date=20200331&type=1&rankingSeq=5&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=032&aid=0003001032&date=20200331&type=1&rankingSeq=6&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=449&aid=0000189238&date=20200331&type=1&rankingSeq=7&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=056&aid=0010812034&date=20200331&type=1&rankingSeq=8&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003343235&date=20200331&type=1&rankingSeq=9&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=422&aid=0000421982&date=20200331&type=2&rankingSeq=10&rankingSectionId=104
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002989078&date=20200331&type=1&rankingSeq=1&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000500358&date=20200331&type=1&rankingSeq=2&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000500688&date=20200331&type=1&rankingSeq=3&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0004386672&date=20200331&type=1&rankingSeq=4&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=138&aid=0002084396&date=20200331&type=1&rankingSeq=5&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003519618&date=20200331&type=1&rankingSeq=6&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=005&aid=0001306221&date=20200331&type=1&rankingSeq=7&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0004609744&date=20200331&type=1&rankingSeq=8&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=029&aid=0002591244&date=20200330&type=1&rankingSeq=9&rankingSectionId=105
# /main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=092&aid=0002184864&date=20200331&type=1&rankingSeq=10&rankingSectionId=105
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078614
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011512662
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=081&aid=0003078569
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=055&aid=0000804620
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=081&aid=0003078564
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=002&aid=0002128571
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=277&aid=0004653155
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=629&aid=0000020846
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=025&aid=0002989080
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=003&aid=0009787940
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=006&aid=0000101904
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0002989104
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011512849
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=028&aid=0002491652
# https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=031&aid=0000532250

# %%
import requests
from bs4 import BeautifulSoup


for i in range(100,105,1):
    url='https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1={}'.format(i)
    
    for j in range(1,5):
        link=url+'#&date=%2000:00:00&page={}'.format(j)
        result = requests.get(link)
        article1 = BeautifulSoup(result.content, "html.parser")
        #print(article1)
        ul=article1.find("div",{"class":"list_body section_index"})
        #print(ul)
        lis=ul.find("a",{"href":"nclicks"})
        print(lis)
        
        #ul=articls1=
#         lis=news.find_All('a')
        
#         for item in lis:
#             try:
#                 a=item['href']
#                 if 'read.nhn' in a:
#                     print(a)
#             except:
#                 pass
#         break
        
#         links="https://news.naver.com"+a
#         result2=request.get(links)
#         bs_doc=BeautifulSoup(result2.content,"html.parser")
#         times=bs_doc.find("span",{"class":"t11"})
#         b=times.text.replace('\n''')
#         c=[int(s) for s in a.split() if s.isdigit() and len(s) ==4]
#         b=c[0]
#         titles=bs_doc.find("h3",{"class":"tt_head"})
#         c=titles.text.replace('\n','').replace('?','').replace('*','').replace('/','').replace("\\",'').replace('<','').replace('>','').split('-')[0]
#         c=c.lstrip().rstrip()
#         docs=bs_doc.find("div",{"class":"_article_body_contents"})
        
#         f = open('D:/python/stock/'+str(a)+'-'+str(b)+'.txt', 'w',encoding='utf-8')
        
#         fname = f
#         f.write(txt)
#         f.close()
#         for item in news:
#             atag=item.find("a")
#             links='https://news.naver.com/'+atag["href"]
#             print(link, atag.text)
        
        
        
#                 content = article1.find("div",{"id":"wrap"})
#         news = content.findAll("div",{"class":"section_body"})
        
#         for item in news:
#             atag = item.find("a")
#             print(atag)
    
#     for item in rprts:
#         atag = item.find("a")
#         link = "https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100#&date=%2000:00:00&page={}"+atag['href']
#         #print(link, atag.text)
#         result2 = requests.get(link)
#         bs_doc = BeautifulSoup(result2.content,"html.parser")
#         times = bs_doc.find("time",{'class':'publication-date-value'})
#         #print(times)
#         a=times.text.replace('\n','')
#         b=[int(s) for s in a.split() if s.isdigit() and len(s)==4]
#         a=b[0]
        
#         docs = bs_doc.find("div",{"class":"article-page"})
#         titles = docs.find("h1",{"class":'heading-title'})
#         b=titles.text.replace('\n','').replace('?','').replace('*','').replace('/','').replace("\\",'').replace('<','').replace('>','').split('-')[0]
#         b=b.lstrip().rstrip()
#         try:
#             abstracts = bs_doc.find('div',{'class':'abstract-content selected'})
#             txt = abstracts.find('p').text.strip()
#         except:
#             pass
#         #print(txt)
        
        
#         f = open('D:/python/project_image/'+str(a)+'-'+str(b)+'.txt', 'w',encoding='utf-8')
        
#         fname = f
#         f.write(txt)
#         f.close()
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
import requests
from bs4 import BeautifulSoup

plusUrl = input('종목코드:')

def refine_price(text):
    price=int(text.replace(",",""))
    return price


for i in range(2):
    #url='https://finance.naver.com/item/sise.nhn?code='+str(plusUrl)+'&page={}'.format(i)
    url='https://finance.naver.com/item/sise_day.nhn?code=051910&page=3'
    response=requests.get(url)
    text=response.text
    html=BeautifulSoup(text,'html.parser')
    table0=html.find_all("tr",{"onmouseover":"mouseOver(this)"})
    print(url)
    
    table1_df=table1_df[['날짜','종가','상승/하락','시가','고가','저가','거래량']]
    
    for tr in table0:
        date= tr.find_all('td')[0].text
        temp=[]  
        
        for td in tr.find_all('td')[1:]:
            price=refine_price(td.text)
            #up=a.find('img')['alt']
            temp.append(price)
            #temp.append(up)
        
        print([date]+temp)


#     cate=[]
#     for a in range(len(cate0)):
#         if a == 2:
#             cate.append(cate0[a].text)
#             cate.append('상승/하락')
#         else:
#             cate.append(cate0[a].text)
    
    
#     main0=bs_obj.find_all("tr",{"onmouseover":"mouseOver(this)"})
    
#     stock=[]
#     for b in range(len(main0)):
#         stock2=[]
#         c=main0[b].find_all('td')
#         for k in range(len(c)):
#             if k ==2:
#                 p=re.compile('[0-9]')
#                 aa = ''.join(p.findall(a[k].text))
#                 stock2.append(aa)
#                 bb=a[k].find('img')['alt']
#                 stock2.append(bb)
#             else:
#                 aa=a[k].text
#                 stock2.append(aa)
#         stock.append(stock2)

# %%
import requests
from bs4 import BeautifulSoup

#plusUrl = input('종목:')

for i in range(1):
    #url='https://finance.naver.com/item/sise.nhn?code='+str(plusUrl)+'&page={}'.format(i)
    url='https://finance.naver.com/item/sise_day.nhn?code=051910&page=3'
    print(url)
    result= requests.get(url)
    bs_obj=BeautifulSoup(result.content,"html.parser")
    table0=bs_obj.find("table",{"class":"type2"})
    cate0=table0.find_all('th')
    
#     cate=[]
#     for j in range(len(cate0)):
#         if j ==2:
#             cate.append(cate0[i].text)
#             cate.append('상승/하락')
#         else:
#             cate.append(cate0[i].text)
    
    main0=bs_obj.find_all("tr",{"onmouseover":"mouseOver(this)"})
    print(main0)
    a=[]
    for main in main0:
        try:
            a.append(main.text.strip().replace('\t','').replace('\n',' '))
        except:
            pass
    
    print(a)
#     stock=[]
#     for k in range(len(main0)):
#         stock2=[]
#         a = main0[i].find_all('td')
#         for l in range(len(a)):
#             if l ==2:
#                 p = re.compile('[0-9]')
#                 aa = ''.join(p.findall(a[l].text))
#                 stocks2.append(aa)
#                 bb=a[l].find('img')['alt']
#                 stocks2.append(bb)
#             else:
#                 aa = a[l].text
#                 stock2.append(aa)
#         stock.append(stock2)

# %%
import requests
from bs4 import BeautifulSoup


url='https://finance.naver.com/item/sise_day.nhn?code=051910&page=1'
print(url)
result= requests.get(url)
bs_obj=BeautifulSoup(result.content,"html.parser")
items=bs_obj.find_all("tr",{"onmouseover":"mouseOver(this)"})
print(items)
a=[]
for item in items:
    try:
        a.append(item.text.strip().replace('\t','').replace('\n',' '))
    except:
        pass
    
print(a)

# %%
import pandas as pd
code_df = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13', header=0)[0]

code_df.종목코드 = code_df.종목코드.map('{:06d}'.format)
code_df = code_df[['회사명', '종목코드']]

code_df = code_df.rename(columns={'회사명': 'name', '종목코드': 'code'}) 
code_df.head()

# %%
def get_url(item_name, code_df):
    code = code_df.query("name=='{}'".format(item_name))['code'].to_string(index=False) 
    url = 'http://finance.naver.com/item/sise_day.nhn?code={code}'.format(code=code) 
    print("요청 URL={}".format(url)) 
    return url

item_name='신라젠'
url = get_url(item_name, code_df)

df = pd.DataFrame()

for page in range(1, 21): 
    pg_url ='{url}&page={page}'.format(url=url, page=page) 
    df=df.append(pd.read_html(pg_url, header=0)[0], ignore_index=True)

df = df.dropna()

df.head()

# %%
df_
