# %%
#import pandas as pd
df1=pd.read_csv('d:/python/stock/Article_IT과학_201901_202004.csv',encoding='ms949',header=None)
df1.head()
# Out:
#           0     1            2                                  3  \
# 0        날짜  카테고리          언론사                                 제목
# 1  20190101  IT과학         이데일리    여기어때 고객 이메일 유출..일괄 발송 설정때문 사과공지
# 2  20190101  IT과학         전자신문  NIPA AI융합본부 신설 등 신SW산업 육성 조직개편 단행
# 3  20190101  IT과학  ZDNet Korea       멜론·지니 음원가격 인상...권리자 권익 향상 목적
# 4  20190101  IT과학        아시아경제  창작자몫 저작권료 5% 오르자 음원서비스 이용료 30% 인상
#
#                                                    4  \
# 0                                                 내용
# 1  이데일리 김현아 기자 여기어때의 이메일 유출 관련 공지 출처 여기어때 홈페이지 . ...
# 2  정보통신산업진흥원 원장 김창용·NIPA 은 AI융합산업본부와 ICT생태계본부 싱크탱...
# 3  저작권 징수규정 개정안 적용...신규가입자 대상 지디넷코리아 안희정 기자 멜론과 지...
# 4  멜론·벅스·지니 등 일제히 가격 인상… 원가 인상에 따른 것 아시아경제 이민우 기자...
#
#                                                    5
# 0                                                URL
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df1.rename(columns={df1.columns[0]:"date",
                   df1.columns[1]:"category",
                   df1.columns[2]:"company",
                   df1.columns[3]:"title",
                   df1.columns[4]:"content",
                   df1.columns[5]:"URL"},inplace=True)

# %%
df1.to_csv('D:/python/stock/Article_IT과학_201901_202004.csv', index=False, encoding='ms949')
df1.head()
# Out:
#        date category      company                              title  \
# 0        날짜     카테고리          언론사                                 제목
# 1  20190101     IT과학         이데일리    여기어때 고객 이메일 유출..일괄 발송 설정때문 사과공지
# 2  20190101     IT과학         전자신문  NIPA AI융합본부 신설 등 신SW산업 육성 조직개편 단행
# 3  20190101     IT과학  ZDNet Korea       멜론·지니 음원가격 인상...권리자 권익 향상 목적
# 4  20190101     IT과학        아시아경제  창작자몫 저작권료 5% 오르자 음원서비스 이용료 30% 인상
#
#                                              content  \
# 0                                                 내용
# 1  이데일리 김현아 기자 여기어때의 이메일 유출 관련 공지 출처 여기어때 홈페이지 . ...
# 2  정보통신산업진흥원 원장 김창용·NIPA 은 AI융합산업본부와 ICT생태계본부 싱크탱...
# 3  저작권 징수규정 개정안 적용...신규가입자 대상 지디넷코리아 안희정 기자 멜론과 지...
# 4  멜론·벅스·지니 등 일제히 가격 인상… 원가 인상에 따른 것 아시아경제 이민우 기자...
#
#                                                  URL
# 0                                                URL
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df2=pd.read_csv('d:/python/stock/Article_economy_201901_202003.csv',encoding='ms949',header=None)
df2.head()
# Out:
#           0        1     2                                          3  \
# 0        날짜     카테고리   언론사                                         제목
# 1  20190101  economy   YTN                    기해년 새해 소망 사자성어 마고소양麻姑搔痒
# 2  20190101  economy   YTN                  지난해 자영업자 경기체감지수 사상 최대폭 하락
# 3  20190101  economy  이데일리           기재부 “비밀 누설로 고발”…신재민 “정부가 사과해야”종합
# 4  20190101  economy  서울경제  이마트 ‘한우 등심’ 6개월간 가격 동결···“33% 할인된 가격에 판매”
#
#                                                    4  \
# 0                                                 내용
# 1  직장인과 구직자 그리고 자영업자들이 새해 소망을 담은 사자성어로 마고소양 을 가장 ...
# 2  지난해 자영업자의 체감 경기지수가 사상 최대 폭으로 떨어진 것으로 나타났습니다. 한...
# 3  2일 검찰 고발 “퇴직 공무원 공무 비밀 엄수해야” 신재민 “내부고발한 것 추가로 ...
# 4  Wet에이징 한우 등심 이마트 서울경제 한우 출하량 감소로 산지 가격 상승이 예상되...
#
#                                                    5
# 0                                                URL
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df2.rename(columns={df2.columns[0]:"date",
                   df2.columns[1]:"category",
                   df2.columns[2]:"company",
                   df2.columns[3]:"title",
                   df2.columns[4]:"content",
                   df2.columns[5]:"URL"},inplace=True)
#"날짜",df2.columns[1]:"카테고리",df2.columns[2]:"언론사",df2.columns[3]:"제목",df2.columns[4]:"내용",df2.columns[5]:"URL"},inplace=True)

# %%
df2.to_csv('D:/python/stock/Article_economy_201901_202003.csv', index=False, encoding='ms949')
df2.head()

# %%
df3=pd.read_csv('d:/python/stock/Article_사회_201901_202003.csv',header=None,encoding='ms949')
df3.head()
# Out:
#           0     1       2                          3  \
# 0        날짜  카테고리     언론사                         제목
# 1  20190101    사회   오마이뉴스  사회서비스 공공성 강화할 대구사회서비스원 설립
# 2  20190101    사회  파이낸셜뉴스     안산상의 지역인재 장학금 800만원 전달
# 3  20190101    사회     뉴스1            대피소에서 밤 보내는 주민들
# 4  20190101    사회     뉴스1     양양 산불로 대피소에서 밤 보내는 주민들
#
#                                                    4  \
# 0                                                 내용
# 1  오는 15일까지 대표 등 임원 모집 절차 들어가 1월 중 설립하고 대구시립희망원 등...
# 2  안산상의경영인협의회 장학금 전달. 사진제공 안산상공회의소 안산 강근주 기자 안산상공...
# 3  양양 뉴스1 서근영 기자 1일 강원도 양양군 서면 송천리 일대 야산에서 발생한 산불...
# 4  양양 뉴스1 서근영 기자 1일 강원도 양양군 서면 송천리 일대 야산에서 발생한 산불...
#
#                                                    5
# 0                                                URL
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df3.rename(columns={df3.columns[0]:"date",
                   df3.columns[1]:"category",
                   df3.columns[2]:"company",
                   df3.columns[3]:"title",
                   df3.columns[4]:"content",
                   df3.columns[5]:"URL"},inplace=True)

# %%
df3.to_csv('D:/python/stock/Article_사회_201901_202003.csv',encoding='ms949', index=False)
df3.head()
# Out:
#        date category company                      title  \
# 0        날짜     카테고리     언론사                         제목
# 1  20190101       사회   오마이뉴스  사회서비스 공공성 강화할 대구사회서비스원 설립
# 2  20190101       사회  파이낸셜뉴스     안산상의 지역인재 장학금 800만원 전달
# 3  20190101       사회     뉴스1            대피소에서 밤 보내는 주민들
# 4  20190101       사회     뉴스1     양양 산불로 대피소에서 밤 보내는 주민들
#
#                                              content  \
# 0                                                 내용
# 1  오는 15일까지 대표 등 임원 모집 절차 들어가 1월 중 설립하고 대구시립희망원 등...
# 2  안산상의경영인협의회 장학금 전달. 사진제공 안산상공회의소 안산 강근주 기자 안산상공...
# 3  양양 뉴스1 서근영 기자 1일 강원도 양양군 서면 송천리 일대 야산에서 발생한 산불...
# 4  양양 뉴스1 서근영 기자 1일 강원도 양양군 서면 송천리 일대 야산에서 발생한 산불...
#
#                                                  URL
# 0                                                URL
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df4=pd.read_csv('d:/python/stock/Article_생활문화_201901_202003.csv',header=None,encoding='ms949')
df4.head()
# Out:
#           0     1       2                                           3  \
# 0        날짜  카테고리     언론사                                          제목
# 1  20190101  생활문화  파이낸셜뉴스                     최길수 작가 광화랑 갤러리에서 개인전 개최
# 2  20190101  생활문화     YTN                날씨 새해 첫 출근길 강추위 계속...미세먼지 보통
# 3  20190101  생활문화    부산일보  바둑열전 제1회 천부배 세계바둑선수권 B조 4강두꺼움의 저력이 서서히 나오다
# 4  20190101  생활문화     YTN                날씨 새해 첫 출근길 맑고 추워...서울 아침 9도
#
#                                                    4  \
# 0                                                 내용
# 1  최길수 작가 개인전 포스터 최길수 작가의 다선 번째 개인전이 오는 9일부터 15일까...
# 2  새해 첫 출근길인 내일 아침에도 예년보다 추운 날씨가 이어집니다. 따뜻한 옷차림으로...
# 3  ○ 신진서 9단·한국 ● 탕웨이싱 9단·중국 흑의 실리가 다소 많은 상황에서 백이 ...
# 4  새해 첫날부터 추위가 만만치 않았는데요. 새해 첫 출근길인 내일 아침에도 예년보다 ...
#
#                                                    5
# 0                                                URL
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df4.rename(columns={df4.columns[0]:"date",
                   df4.columns[1]:"category",
                   df4.columns[2]:"company",
                   df4.columns[3]:"title",
                   df4.columns[4]:"content",
                   df4.columns[5]:"URL"},inplace=True)

# %%
df4.to_csv('D:/python/stock/Article_생활문화_201901_202003.csv',encoding='ms949', index=False)
df4.head()
# Out:
#        date category company                                       title  \
# 0        날짜     카테고리     언론사                                          제목
# 1  20190101     생활문화  파이낸셜뉴스                     최길수 작가 광화랑 갤러리에서 개인전 개최
# 2  20190101     생활문화     YTN                날씨 새해 첫 출근길 강추위 계속...미세먼지 보통
# 3  20190101     생활문화    부산일보  바둑열전 제1회 천부배 세계바둑선수권 B조 4강두꺼움의 저력이 서서히 나오다
# 4  20190101     생활문화     YTN                날씨 새해 첫 출근길 맑고 추워...서울 아침 9도
#
#                                              content  \
# 0                                                 내용
# 1  최길수 작가 개인전 포스터 최길수 작가의 다선 번째 개인전이 오는 9일부터 15일까...
# 2  새해 첫 출근길인 내일 아침에도 예년보다 추운 날씨가 이어집니다. 따뜻한 옷차림으로...
# 3  ○ 신진서 9단·한국 ● 탕웨이싱 9단·중국 흑의 실리가 다소 많은 상황에서 백이 ...
# 4  새해 첫날부터 추위가 만만치 않았는데요. 새해 첫 출근길인 내일 아침에도 예년보다 ...
#
#                                                  URL
# 0                                                URL
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df5=pd.read_csv('d:/python/stock/Article_세계_201901_202003.csv',header=None,encoding='ms949')
df5.head()
# Out:
#           0     1     2                                     3  \
# 0        날짜  카테고리   언론사                                    제목
# 1  20190101    세계  연합뉴스    재담판 의지새길 경고 김정은 강온 투트랙…트럼프 응답 주목종합
# 2  20190101    세계  연합뉴스  러 우랄 아파트 붕괴 현장서 11개월 남자아이 기적적 구조종합2보
# 3  20190101    세계   YTN                英 경찰 맨체스터역 흉기 난동은 테러사건
# 4  20190101    세계   YTN                英 경찰 맨체스터역 흉기 난동은 테러사건
#
#                                                    4  \
# 0                                                 내용
# 1  공 넘겨받은 트럼프 반응 관건… 톱다운 해결 의지표명에 2차핵담판 호응 가능성 가시...
# 2  이불 쌓여 침대에 눕혀져 있어 생존…뇌진탕·동상 등으로 중태 사망자 8명 30여명 ...
# 3  영국 경찰이 맨체스터 빅토리아역의 흉기 난동을 테러 사건으로 취급해 수사하고 있습니...
# 4  영국 경찰이 맨체스터 빅토리아역의 흉기 난동을 테러 사건으로 취급해 수사하고 있습니...
#
#                                                    5
# 0                                                URL
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df5.rename(columns={df5.columns[0]:"date",
                   df5.columns[1]:"category",
                   df5.columns[2]:"company",
                   df5.columns[3]:"title",
                   df5.columns[4]:"content",
                   df5.columns[5]:"URL"},inplace=True)

# %%
df5.to_csv('D:/python/stock/Article_세계_201901_202003.csv',encoding='ms949',index=False)
df5.head()
# Out:
#        date category company                                 title  \
# 0        날짜     카테고리     언론사                                    제목
# 1  20190101       세계    연합뉴스    재담판 의지새길 경고 김정은 강온 투트랙…트럼프 응답 주목종합
# 2  20190101       세계    연합뉴스  러 우랄 아파트 붕괴 현장서 11개월 남자아이 기적적 구조종합2보
# 3  20190101       세계     YTN                英 경찰 맨체스터역 흉기 난동은 테러사건
# 4  20190101       세계     YTN                英 경찰 맨체스터역 흉기 난동은 테러사건
#
#                                              content  \
# 0                                                 내용
# 1  공 넘겨받은 트럼프 반응 관건… 톱다운 해결 의지표명에 2차핵담판 호응 가능성 가시...
# 2  이불 쌓여 침대에 눕혀져 있어 생존…뇌진탕·동상 등으로 중태 사망자 8명 30여명 ...
# 3  영국 경찰이 맨체스터 빅토리아역의 흉기 난동을 테러 사건으로 취급해 수사하고 있습니...
# 4  영국 경찰이 맨체스터 빅토리아역의 흉기 난동을 테러 사건으로 취급해 수사하고 있습니...
#
#                                                  URL
# 0                                                URL
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df6=pd.read_csv('d:/python/stock/Article_정치_201901_202003.csv',header=None,encoding='ms949')
df6.head()
# Out:
#           0     1     2                                    3  \
# 0        날짜  카테고리   언론사                                   제목
# 1  20190101    정치   뉴시스      강경화 비핵화 진전 이뤄지면 종전선언도 이뤄지지 않을까
# 2  20190101    정치  이데일리  강경화 외교장관 “美 北 비핵화 위해 종전선언 카드 사용 가능”
# 3  20190101    정치  연합뉴스       조명균 남북간 정리할 일 있어…고위급회담 개최여부 검토
# 4  20190101    정치  이데일리     정경두 국방장관 종전선언해도 군대가야…모병제 전환 시기상조
#
#                                                    4  \
# 0                                                 내용
# 1  서울 뉴시스 박미소 수습기자 14일 오전 서울 종로구 외교부에서 열린 재외공관장회의...
# 2  종전선언은 평화체제 첫 관문…남북미간 계기 될 수 있어 북미정상회담 위한 접촉 진행...
# 3  조명균 통일부 장관 연합뉴스 자료사진 서울 연합뉴스 이상현 기자 조명균 통일부 장관...
# 4  이데일리 김관용 기자 정경두 국방부 장관은 1일 최근 남북 관계에 훈풍이 불고 있지...
#
#                                                    5
# 0                                                URL
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df6.rename(columns={df6.columns[0]:"date",
                   df6.columns[1]:"category",
                   df6.columns[2]:"company",
                   df6.columns[3]:"title",
                   df6.columns[4]:"content",
                   df6.columns[5]:"URL"},inplace=True)

# %%
df6.to_csv('D:/python/stock/Article_정치_201901_202003.csv',encoding='ms949', index=False)
df6.head()
# Out:
#        date category company                                title  \
# 0        날짜     카테고리     언론사                                   제목
# 1  20190101       정치     뉴시스      강경화 비핵화 진전 이뤄지면 종전선언도 이뤄지지 않을까
# 2  20190101       정치    이데일리  강경화 외교장관 “美 北 비핵화 위해 종전선언 카드 사용 가능”
# 3  20190101       정치    연합뉴스       조명균 남북간 정리할 일 있어…고위급회담 개최여부 검토
# 4  20190101       정치    이데일리     정경두 국방장관 종전선언해도 군대가야…모병제 전환 시기상조
#
#                                              content  \
# 0                                                 내용
# 1  서울 뉴시스 박미소 수습기자 14일 오전 서울 종로구 외교부에서 열린 재외공관장회의...
# 2  종전선언은 평화체제 첫 관문…남북미간 계기 될 수 있어 북미정상회담 위한 접촉 진행...
# 3  조명균 통일부 장관 연합뉴스 자료사진 서울 연합뉴스 이상현 기자 조명균 통일부 장관...
# 4  이데일리 김관용 기자 정경두 국방부 장관은 1일 최근 남북 관계에 훈풍이 불고 있지...
#
#                                                  URL
# 0                                                URL
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
import pandas as pd
import glob
import os

input_file = 'd:/python/stock' # csv파일들이 있는 디렉토리 위치
output_file = 'd:/python/stock/article.csv' # 병합하고 저장하려는 파일명

allFile_list = glob.glob(os.path.join(input_file, 'Article_*')) # glob함수로 sales_로 시작하는 파일들을 모은다
print(allFile_list)
allData = [] # 읽어 들인 csv파일 내용을 저장할 빈 리스트를 하나 만든다

for file in allFile_list:
    df = pd.read_csv(file,encoding='ms949') # for구문으로 csv파일들을 읽어 들인다
    allData.append(df) # 빈 리스트에 읽어 들인 내용을 추가한다

dataCombine = pd.concat(allData, axis=0, ignore_index=True) # concat함수를 이용해서 리스트의 내용을 병합
# axis=0은 수직으로 병합함. axis=1은 수평. ignore_index=True는 인데스 값이 기존 순서를 무시하고 순서대로 정렬되도록 한다.
dataCombine.to_csv(output_file,index=False,encoding='euc-kr') # to_csv함수로 저장한다. 인데스를 빼려면 False로 설정
# Out:
# ['d:/python/stock\\Article_economy_201901_202003.csv', 'd:/python/stock\\Article_IT과학_201901_202004.csv', 'd:/python/stock\\Article_사회_201901_202003.csv', 'd:/python/stock\\Article_생활문화_201901_202003.csv', 'd:/python/stock\\Article_세계_201901_202003.csv', 'd:/python/stock\\Article_정치_201901_202003.csv']

# %%
df7=pd.read_csv('d:/python/stock/article.csv',encoding='ms949')
df7.head()
# Out:
#        date       date2 category company  \
# 0  20190101  2019-01-01  economy     YTN
# 1  20190101  2019-01-01  economy     YTN
# 2  20190101  2019-01-01  economy    이데일리
# 3  20190101  2019-01-01  economy    서울경제
# 4  20190101  2019-01-01  economy    이데일리
#
#                                        title  \
# 0                    기해년 새해 소망 사자성어 마고소양麻姑搔痒
# 1                  지난해 자영업자 경기체감지수 사상 최대폭 하락
# 2           기재부 “비밀 누설로 고발”…신재민 “정부가 사과해야”종합
# 3  이마트 ‘한우 등심’ 6개월간 가격 동결···“33% 할인된 가격에 판매”
# 4          이낙연 총리 일자리 지표 좋아져…정책기조 유지 부작용 최소화
#
#                                              content  \
# 0  직장인과 구직자 그리고 자영업자들이 새해 소망을 담은 사자성어로 마고소양 을 가장 ...
# 1  지난해 자영업자의 체감 경기지수가 사상 최대 폭으로 떨어진 것으로 나타났습니다. 한...
# 2  2일 검찰 고발 “퇴직 공무원 공무 비밀 엄수해야” 신재민 “내부고발한 것 추가로 ...
# 3  Wet에이징 한우 등심 이마트 서울경제 한우 출하량 감소로 산지 가격 상승이 예상되...
# 4  집권 3년차 투자와 고용 특단의 대책 추진하겠다 밝혀 정책기조는 그대로 유지하되 부...
#
#                                                  URL
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df7['date2']=pd.to_datetime(df7['date2'], format="%Y/%m/%d")
df7.set_index('date2', inplace=True)
df7.head()
# Out:
#                 date category company  \
# date2
# 2019-01-01  20190101  economy     YTN
# 2019-01-01  20190101  economy     YTN
# 2019-01-01  20190101  economy    이데일리
# 2019-01-01  20190101  economy    서울경제
# 2019-01-01  20190101  economy    이데일리
#
#                                                 title  \
# date2
# 2019-01-01                    기해년 새해 소망 사자성어 마고소양麻姑搔痒
# 2019-01-01                  지난해 자영업자 경기체감지수 사상 최대폭 하락
# 2019-01-01           기재부 “비밀 누설로 고발”…신재민 “정부가 사과해야”종합
# 2019-01-01  이마트 ‘한우 등심’ 6개월간 가격 동결···“33% 할인된 가격에 판매”
# 2019-01-01          이낙연 총리 일자리 지표 좋아져…정책기조 유지 부작용 최소화
#
#                                                       content  \
# date2
# 2019-01-01  직장인과 구직자 그리고 자영업자들이 새해 소망을 담은 사자성어로 마고소양 을 가장 ...
# 2019-01-01  지난해 자영업자의 체감 경기지수가 사상 최대 폭으로 떨어진 것으로 나타났습니다. 한...
# 2019-01-01  2일 검찰 고발 “퇴직 공무원 공무 비밀 엄수해야” 신재민 “내부고발한 것 추가로 ...
# 2019-01-01  Wet에이징 한우 등심 이마트 서울경제 한우 출하량 감소로 산지 가격 상승이 예상되...
# 2019-01-01  집권 3년차 투자와 고용 특단의 대책 추진하겠다 밝혀 정책기조는 그대로 유지하되 부...
#
#                                                           URL
# date2
# 2019-01-01  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2019-01-01  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2019-01-01  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2019-01-01  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2019-01-01  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
del df7["date"]
df7.head()
# Out:
#            category company                                      title  \
# date2
# 2019-01-01  economy     YTN                    기해년 새해 소망 사자성어 마고소양麻姑搔痒
# 2019-01-01  economy     YTN                  지난해 자영업자 경기체감지수 사상 최대폭 하락
# 2019-01-01  economy    이데일리           기재부 “비밀 누설로 고발”…신재민 “정부가 사과해야”종합
# 2019-01-01  economy    서울경제  이마트 ‘한우 등심’ 6개월간 가격 동결···“33% 할인된 가격에 판매”
# 2019-01-01  economy    이데일리          이낙연 총리 일자리 지표 좋아져…정책기조 유지 부작용 최소화
#
#                                                       content  \
# date2
# 2019-01-01  직장인과 구직자 그리고 자영업자들이 새해 소망을 담은 사자성어로 마고소양 을 가장 ...
# 2019-01-01  지난해 자영업자의 체감 경기지수가 사상 최대 폭으로 떨어진 것으로 나타났습니다. 한...
# 2019-01-01  2일 검찰 고발 “퇴직 공무원 공무 비밀 엄수해야” 신재민 “내부고발한 것 추가로 ...
# 2019-01-01  Wet에이징 한우 등심 이마트 서울경제 한우 출하량 감소로 산지 가격 상승이 예상되...
# 2019-01-01  집권 3년차 투자와 고용 특단의 대책 추진하겠다 밝혀 정책기조는 그대로 유지하되 부...
#
#                                                           URL
# date2
# 2019-01-01  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2019-01-01  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2019-01-01  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2019-01-01  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2019-01-01  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
merged_dataframe=df7['date2','category','company','title','content','URL'].merge(df_stock, how='inner',on='date2',left_index=True)
print(merged_dataframe.shape)
merged_dataframe.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('date2', 'category', 'company', 'title', 'content', 'URL')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-7f665429be6b> in <module>
# ----> 1 merged_dataframe=df7['date2','category','company','title','content','URL'].merge(df_stock, how='inner',on='date2',left_index=True)
#       2 print(merged_dataframe.shape)
#       3 merged_dataframe.head()
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('date2', 'category', 'company', 'title', 'content', 'URL')

# %%
#csv->txt

# %%
a=df6['날짜']
b=df6['내용']
c=zip(a,b)
with open('d:/python/stock/article.txt','w') as f:
    #n=0
    for i in c:
        #n+=1
        #if n==10: break
        day=str(i[0])
        contents=str(i[1])
        f.write(day+'\n'+contents+'\n')

# %%
#한글 뉴스 분석
f=open('d:/python/stock/article.txt',encoding='ms949')
lines=f.readlines()
f.close()
print(lines[:100])

# %%
# rows=[]
# for line in lines:
#     rows.append(line.replace('\n','')) #줄바꿈 문자 제거
    
# rows

# %%
from konlpy.tag import Hannanum
han=Hannanum()

# %%
temp=[]
for i in range(len(lines)):
    temp.append(han.nouns(lines[i])) #명사만 추출하여 저장
    
print(temp)

# %%
def flatten(items):
    flatList=[]
    for elem in items:
        if type(elem) == list: #자료형이 리스트이면
            for e in elem:
                flatList.append(e)
        else:
            flatList.append(elem)
    return flatList

word_list=flatten(temp)
#글자수가 2글자 이상인 단어들만 선택
word_list=pd.Series([x for x in word_list if len(x)>1])
print(word_list)

# %%
stopwords=['이날','03.','본문','오전','2020.','05','텍스트',
          '5일(한국시간)','기사입력','09','10','10','02','기사원문',
          '평가하기공감댓글수4','최종수정','[STN스포츠=이형주','57']
word_list2=[i for i in word_list if i not in stopwords]
word_list2

# %%
#https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100

# %%
import requests
from bs4 import BeautifulSoup


for i in range(100,105,1):
    url='https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1={}'.format(i)
    
    for j in range(1,5):
        link=url+'#&date=%2000:00:00&page={}'.format(j)
        result = requests.get(link)
        article1 = BeautifulSoup(result.content, "html.parser")
        lis=article1.select('a')
        
        for item in lis:
            try:
                a=item['href']
                if 'read.nhn' in a:
                    print(a)
            except:
                pass
        break
        
#         links="https://news.naver.com/"+a
#         result2=request.get(links)
#         bs_doc=BeautifulSoup(result2.content,"html.parser")
#         times=bs_doc.find("span",{"class":"t11"})
#         b=times.text.replace('\n''')
#         c=[int(s) for s in a.split() if s.isdigit() and len(s) ==4]
#         b=c[0]
#         titles=bs_doc.find("h3",{"class":"tt_head"})
#         c=titles.text.replace('\n','').replace('?','').replace('*','').replace('/','').replace("\\",'').replace('<','').replace('>','').split('-')[0]
#         c=c.lstrip().rstrip()
#         docs=bs_doc.find("div",{"class":"_article_body_contents"})
        
#         f = open('D:/python/stock/'+str(a)+'-'+str(b)+'.txt', 'w',encoding='utf-8')
        
#         fname = f
#         f.write(txt)
#         f.close()

# %%
import requests
from bs4 import BeautifulSoup


for i in range(100,105,1):
    url='https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1={}'.format(i)
    
    for j in range(1,5):
        link=url+'#&date=%2000:00:00&page={}'.format(j)
        result = requests.get(link)
        article1 = BeautifulSoup(result.content, "html.parser")
        #print(article1)
        ul=article1.find("div",{"class":"list_body section_index"})
        #print(ul)
        lis=ul.find("a",{"href":"nclicks"})
        print(lis)
        
        #ul=articls1=
#         lis=news.find_All('a')
        
#         for item in lis:
#             try:
#                 a=item['href']
#                 if 'read.nhn' in a:
#                     print(a)
#             except:
#                 pass
#         break
        
#         links="https://news.naver.com"+a
#         result2=request.get(links)
#         bs_doc=BeautifulSoup(result2.content,"html.parser")
#         times=bs_doc.find("span",{"class":"t11"})
#         b=times.text.replace('\n''')
#         c=[int(s) for s in a.split() if s.isdigit() and len(s) ==4]
#         b=c[0]
#         titles=bs_doc.find("h3",{"class":"tt_head"})
#         c=titles.text.replace('\n','').replace('?','').replace('*','').replace('/','').replace("\\",'').replace('<','').replace('>','').split('-')[0]
#         c=c.lstrip().rstrip()
#         docs=bs_doc.find("div",{"class":"_article_body_contents"})
        
#         f = open('D:/python/stock/'+str(a)+'-'+str(b)+'.txt', 'w',encoding='utf-8')
        
#         fname = f
#         f.write(txt)
#         f.close()
#         for item in news:
#             atag=item.find("a")
#             links='https://news.naver.com/'+atag["href"]
#             print(link, atag.text)
        
        
        
#                 content = article1.find("div",{"id":"wrap"})
#         news = content.findAll("div",{"class":"section_body"})
        
#         for item in news:
#             atag = item.find("a")
#             print(atag)
    
#     for item in rprts:
#         atag = item.find("a")
#         link = "https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100#&date=%2000:00:00&page={}"+atag['href']
#         #print(link, atag.text)
#         result2 = requests.get(link)
#         bs_doc = BeautifulSoup(result2.content,"html.parser")
#         times = bs_doc.find("time",{'class':'publication-date-value'})
#         #print(times)
#         a=times.text.replace('\n','')
#         b=[int(s) for s in a.split() if s.isdigit() and len(s)==4]
#         a=b[0]
        
#         docs = bs_doc.find("div",{"class":"article-page"})
#         titles = docs.find("h1",{"class":'heading-title'})
#         b=titles.text.replace('\n','').replace('?','').replace('*','').replace('/','').replace("\\",'').replace('<','').replace('>','').split('-')[0]
#         b=b.lstrip().rstrip()
#         try:
#             abstracts = bs_doc.find('div',{'class':'abstract-content selected'})
#             txt = abstracts.find('p').text.strip()
#         except:
#             pass
#         #print(txt)
        
        
#         f = open('D:/python/project_image/'+str(a)+'-'+str(b)+'.txt', 'w',encoding='utf-8')
        
#         fname = f
#         f.write(txt)
#         f.close()
